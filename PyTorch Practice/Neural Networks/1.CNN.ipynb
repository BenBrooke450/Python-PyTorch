# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aryashah2k/breast-ultrasound-images-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 195M/195M [00:04<00:00, 42.2MB/s]
# Extracting model files...
# Path to dataset files: /Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1

# %%
import os

f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/benign"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/benign")

# %%
import shutil

direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/benign"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/benign"


for png in os.listdir(direction_take):
    print(png)
    if png.endswith(").png"):

        old_path = os.path.join(direction_take,png)
        new_path = os.path.join(direction_put,png)

        shutil.copy(old_path,new_path)
# Out:
# benign (246)_mask.png
# benign (328).png
# benign (282).png
# benign (136)_mask.png
# benign (300)_mask.png
# benign (144).png
# benign (87)_mask.png
# benign (82).png
# benign (185)_mask.png
# benign (390).png
# benign (34)_mask.png
# benign (113).png
# benign (406).png
# benign (369).png
# benign (386).png
# benign (20)_mask.png
# benign (105).png
# benign (228)_mask.png
# benign (191)_mask.png
# benign (158)_mask.png
# benign (410).png
# benign (294).png
# benign (93)_mask.png
# benign (314)_mask.png
# benign (408)_mask.png
# benign (122)_mask.png
# benign (152).png
# benign (252)_mask.png
# benign (94).png
# benign (200).png
# benign (345).png
# benign (209)_mask.png
# benign (179)_mask.png
# benign (129).png
# benign (386)_mask.png
# benign (257).png
# benign (312).png
# benign (54)_mask_1.png
# benign (103)_mask.png
# benign (429)_mask.png
# benign (191).png
# benign (335)_mask.png
# benign (273)_mask.png
# benign (57).png
# benign (267)_mask.png
# benign (241).png
# ...

# %%
for png in os.listdir(direction_put):
    print(png)
# Out:
# benign (328).png
# benign (282).png
# benign (144).png
# benign (82).png
# benign (390).png
# benign (113).png
# benign (406).png
# benign (369).png
# benign (386).png
# benign (105).png
# benign (410).png
# benign (294).png
# benign (152).png
# benign (94).png
# benign (200).png
# benign (345).png
# benign (129).png
# benign (257).png
# benign (312).png
# benign (191).png
# benign (57).png
# benign (241).png
# benign (304).png
# benign (187).png
# benign (41).png
# benign (168).png
# benign (216).png
# benign (353).png
# benign (16).png
# benign (61).png
# benign (148).png
# benign (324).png
# benign (261).png
# benign (36).png
# benign (373).png
# benign (236).png
# benign (20).png
# benign (109).png
# benign (365).png
# benign (220).png
# benign (77).png
# benign (98).png
# benign (332).png
# benign (298).png
# benign (277).png
# benign (2).png
# benign (430).png
# benign (125).png
# benign (349).png
# benign (172).png
# benign (164).png
# benign (308).png
# benign (426).png
# ...

# %%
f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/malignant"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/malignant")


direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/malignant"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/malignant"


for png in os.listdir(direction_take):
    if png.endswith(").png"):

        old_path = os.path.join(direction_take,png)
        new_path = os.path.join(direction_put,png)

        shutil.copy(old_path,new_path)

# %%
f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/normal"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/normal")


direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/normal"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/normal"


for png in os.listdir(direction_take):
    if png.endswith(").png"):

        old_path = os.path.join(direction_take,png)
        new_path = os.path.join(direction_put,png)

        shutil.copy(old_path,new_path)
