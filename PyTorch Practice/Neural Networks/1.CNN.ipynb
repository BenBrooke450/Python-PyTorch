# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aryashah2k/breast-ultrasound-images-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1

# %%
import os

f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/benign"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/benign")




f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/benign"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/benign")

# %%
import shutil

direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/benign"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/benign"

i = 0
j = 0

for png in os.listdir(direction_take):
    if png.endswith(").png"):
        i = i + 1

        if i > 100:
            j = j + 1
            old_path = os.path.join(direction_take,png)
            new_path = os.path.join(direction_put,png)

            shutil.copy(old_path,new_path)

print(i,j)
# Out:
# 437 337

# %%
direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/benign"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/benign"

i = 0
j = 0

for png in os.listdir(direction_take):
    j = j + 1
    if png.endswith(").png") and i <= 100:
        old_path = os.path.join(direction_take,png)
        new_path = os.path.join(direction_put,png)

        shutil.copy(old_path,new_path)
        i = i + 1

print(i,j)
# Out:
# 101 891

# %%
for png in os.listdir(direction_put):
    print(png)
# Out:
# benign (328).png
# benign (282).png
# benign (144).png
# benign (82).png
# benign (390).png
# benign (113).png
# benign (406).png
# benign (369).png
# benign (386).png
# benign (105).png
# benign (410).png
# benign (294).png
# benign (152).png
# benign (94).png
# benign (200).png
# benign (345).png
# benign (129).png
# benign (257).png
# benign (312).png
# benign (191).png
# benign (57).png
# benign (241).png
# benign (304).png
# benign (187).png
# benign (41).png
# benign (168).png
# benign (216).png
# benign (353).png
# benign (16).png
# benign (61).png
# benign (148).png
# benign (324).png
# benign (261).png
# benign (36).png
# benign (373).png
# benign (236).png
# benign (20).png
# benign (109).png
# benign (365).png
# benign (220).png
# benign (77).png
# benign (98).png
# benign (332).png
# benign (298).png
# benign (277).png
# benign (2).png
# benign (430).png
# benign (125).png
# benign (349).png
# benign (172).png
# benign (164).png
# benign (308).png
# benign (426).png
# ...

# %%
f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/malignant"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/malignant")


direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/malignant"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/malignant"

i = 0
j = 0

for png in os.listdir(direction_take):
    if png.endswith(").png"):
        i = i + 1
        if i > 100:
            j = j + 1
            old_path = os.path.join(direction_take,png)
            new_path = os.path.join(direction_put,png)

            shutil.copy(old_path,new_path)

print(i,j)
# Out:
# 210 110

# %%
f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/malignant"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/malignant")


direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/malignant"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/malignant"

i = 0
j = 0

for png in os.listdir(direction_take):
    j = j + 1
    if png.endswith(").png") and i <= 100:

        old_path = os.path.join(direction_take,png)
        new_path = os.path.join(direction_put,png)

        shutil.copy(old_path,new_path)

        i = i + 1

print(i,j)
# Out:
# 101 421

# %%
f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/normal"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/normal")


direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/normal"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data/normal"

i = 0
j = 0

for png in os.listdir(direction_take):
    if png.endswith(").png"):
        i = i + 1
        if i > 100:
            j = j + 1
            old_path = os.path.join(direction_take,png)
            new_path = os.path.join(direction_put,png)

            shutil.copy(old_path,new_path)

print(i,j)
# Out:
# 133 33

# %%
f = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/normal"

if os.path.exists(f):
    pass
else:
    os.makedirs("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/normal")


direction_take = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/normal"

direction_put = "/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data/normal"

i = 0

for png in os.listdir(direction_take):
    if png.endswith(").png") and i <= 100:

        old_path = os.path.join(direction_take,png)
        new_path = os.path.join(direction_put,png)
        shutil.copy(old_path,new_path)
        i = i + 1

# %%
import torch
from torch import nn

from torch.utils.data import DataLoader
from torchvision import transforms, datasets




Train_dataset = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor()])
Test_dataset = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor()])

train_dataset = datasets.ImageFolder("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Train_data",Train_dataset)
test_dataset = datasets.ImageFolder("/Users/benjaminbrooke/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/Test_data",Test_dataset)


train_loader = DataLoader(train_dataset,batch_size=10,shuffle=True)
test_loader = DataLoader(test_dataset,batch_size=1,shuffle=True)

# %%
for X_val,y_val in train_loader:
    print(X_val,y_val)
# Out:
# tensor([[[[0.4745, 0.4941, 0.5647,  ..., 0.5686, 0.5804, 0.5961],
#           [0.4784, 0.5176, 0.5608,  ..., 0.5137, 0.5333, 0.5490],
#           [0.5176, 0.5490, 0.5843,  ..., 0.7176, 0.6941, 0.6745],
#           ...,
#           [0.0157, 0.0471, 0.0667,  ..., 0.0784, 0.0235, 0.0353],
#           [0.0235, 0.0275, 0.0353,  ..., 0.0745, 0.0627, 0.0745],
#           [0.0235, 0.0392, 0.0471,  ..., 0.0667, 0.0784, 0.0824]],
#
#          [[0.4745, 0.4941, 0.5647,  ..., 0.5686, 0.5804, 0.5961],
#           [0.4784, 0.5176, 0.5608,  ..., 0.5137, 0.5333, 0.5490],
#           [0.5176, 0.5490, 0.5843,  ..., 0.7176, 0.6941, 0.6745],
#           ...,
#           [0.0157, 0.0471, 0.0667,  ..., 0.0784, 0.0235, 0.0353],
#           [0.0235, 0.0275, 0.0353,  ..., 0.0745, 0.0627, 0.0745],
#           [0.0235, 0.0392, 0.0471,  ..., 0.0667, 0.0784, 0.0824]],
#
#          [[0.4745, 0.4941, 0.5647,  ..., 0.5686, 0.5804, 0.5961],
#           [0.4784, 0.5176, 0.5608,  ..., 0.5137, 0.5333, 0.5490],
# ...

# %%
class MedicalImageModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.convo_layer_one = nn.Conv2d(3,5,2)
        self.activation_one = nn.ReLU()
        self.pool_one = nn.MaxPool2d(kernel_size=4,stride=2)

        self.convo_layer_two = nn.Conv2d(5,10,2)
        self.activation_two = nn.ReLU()
        self.pool_two = nn.MaxPool2d(kernel_size=4,stride=2)

        self.convo_layer_three = nn.Conv2d(10,5,2)
        self.activation_three = nn.ReLU()
        self.pool_three = nn.MaxPool2d(kernel_size=4,stride=2)

        self.convo_layer_four = nn.Conv2d(5,3,2)
        self.activation_four = nn.ReLU()

        self.flatten =  nn.Flatten()

        self.linear_layer_one = nn.Linear(in_features=1728,out_features=32)
        self.activation_four = nn.ReLU()
        self.linear_layer_two = nn.Linear(in_features=32,out_features=3)

    def forward(self,x):
        x = self.pool_one(self.activation_one(self.convo_layer_one(x)))

        x = self.pool_two(self.activation_two(self.convo_layer_two(x)))

        x = self.pool_three(self.activation_three(self.convo_layer_three(x)))

        x = self.flatten(self.activation_four(self.convo_layer_four(x)))

        return self.linear_layer_two(self.activation_four(self.linear_layer_one(x)))

# %%
model_one = MedicalImageModel()

# %%
"""from collections import Counter

labels = []
for _, y in train_loader:
    labels.extend(y.tolist())

from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

weights = torch.tensor(class_weights, dtype=torch.float32)"""

loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(model_one.parameters(),lr=0.001)

# %%
y_loss = []
x_point = []
i = 0

epochs = 4
model_one.train()

for epoch in range(epochs):

    for x_batch, y_batch in train_loader:

        optimizer.zero_grad()

        y_pred = model_one(x_batch)

        loss = loss_fn(y_pred,y_batch)

        loss.backward()

        optimizer.step()



        x_point.append(i)
        y_loss.append(loss.item())

        i = i + 1

        if epoch % 1 == 0:
            print(f'Epoch {epoch}, Loss: {loss.item()}, y_pred_doftmax: {torch.softmax(y_pred, dim= 1).tolist()}')
# Out:
# Epoch 0, Loss: 1.0929871797561646, y_pred_doftmax: [[0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141], [0.3337864875793457, 0.3426586091518402, 0.3235549032688141]]
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x_point,y_loss)

# %%
model_one.eval()

for x_eval, y_eval in test_loader:

    y_logits = model_one(x_eval)

    y_prob = torch.softmax(y_logits,dim=1)

    _, y_pred = torch.max(y_prob,dim = 1)

    one_hot = torch.nn.functional.one_hot(y_pred, num_classes=3)

    print(f"Probabilities: {y_prob.tolist()}, One hot:{one_hot},  Predictions {y_pred.item()}, Index of list True: {y_eval.item()}")
# Out:
# Probabilities: [[0.5465347766876221, 0.28951507806777954, 0.16395018994808197]], One hot:tensor([[1, 0, 0]]),  Predictions 0, Index of list True: 1
# Probabilities: [[0.5465347766876221, 0.28951507806777954, 0.16395018994808197]], One hot:tensor([[1, 0, 0]]),  Predictions 0, Index of list True: 0
# Probabilities: [[0.5465347766876221, 0.28951507806777954, 0.16395018994808197]], One hot:tensor([[1, 0, 0]]),  Predictions 0, Index of list True: 1
# Probabilities: [[0.5465347766876221, 0.28951507806777954, 0.16395018994808197]], One hot:tensor([[1, 0, 0]]),  Predictions 0, Index of list True: 0
# Probabilities: [[0.5465347766876221, 0.28951507806777954, 0.16395018994808197]], One hot:tensor([[1, 0, 0]]),  Predictions 0, Index of list True: 0
# Probabilities: [[0.5465347766876221, 0.28951507806777954, 0.16395018994808197]], One hot:tensor([[1, 0, 0]]),  Predictions 0, Index of list True: 0
# ...
