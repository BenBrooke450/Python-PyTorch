# %%
import pandas as pd
vocab = pd.read_table("/Users/benjaminbrooke/PycharmProjects/Python_PyTroch/PyTorch Practice/0.Data/The Verdict.txt",encoding='utf-8', header=None)

# %%
print(vocab)
# Out:
#                                                     0
# 0   I HAD always thought Jack Gisburn rather a che...
# 1   The height of his glory--that was what the wom...
# 2   Well!--even through the prism of Hermia's tear...
# 3   It was not till three years later that, in the...
# 4   Of course, if she had not dragged him down, sh...
# ..                                                ...
# 73  If I could have painted that face, with that q...
# 74  He flung himself down in the arm-chair near mi...
# 75  I like to fancy that Stroud himself would have...
# 76  And, in answer to a question I put half-mechan...
# 77  He stood up and laid his hand on my shoulder w...
#
# [78 rows x 1 columns]

# %%
import re
all_words = ""
for x in vocab.values:
    all_words = all_words + x

result = re.split(r'([,.:;?_!"()\']|--|\s)', all_words[0])

result = [item.strip() for item in result if item.strip()]

print(result)
# Out:
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his', 'glory', ',', 'he', 'had', 'dropped', 'his', 'painting', ',', 'married', 'a', 'rich', 'widow', ',', 'and', 'established', 'himself', 'in', 'a', 'villa', 'on', 'the', 'Riviera', '.', '(', 'Though', 'I', 'rather', 'thought', 'it', 'would', 'have', 'been', 'Rome', 'or', 'Florence', '.', ')', 'The', 'height', 'of', 'his', 'glory', '--', 'that', 'was', 'what', 'the', 'women', 'called', 'it', '.', 'I', 'can', 'hear', 'Mrs', '.', 'Gideon', 'Thwing', '--', 'his', 'last', 'Chicago', 'sitter', '--', 'deploring', 'his', 'unaccountable', 'abdication', '.', '"', 'Of', 'course', 'it', "'", 's', 'going', 'to', 'send', 'the', 'value', 'of', 'my', 'picture', "'", 'way', 'up', ';', 'but', 'I', 'don', "'", 't', 'think', 'of', 'that', ',', 'Mr',
# ...

# %%
with open("/Users/benjaminbrooke/PycharmProjects/Python_PyTroch/PyTorch Practice/0.Data/The Verdict.txt", encoding="utf-8") as f:
    text = f.read()

# %%
print(text)
# Out:
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no great surprise to me to hear that, in the height of his glory, he had dropped his painting, married a rich widow, and established himself in a villa on the Riviera. (Though I rather thought it would have been Rome or Florence.)
#
# "The height of his glory"--that was what the women called it. I can hear Mrs. Gideon Thwing--his last Chicago sitter--deploring his unaccountable abdication. "Of course it's going to send the value of my picture 'way up; but I don't think of that, Mr. Rickham--the loss to Arrt is all I think of." The word, on Mrs. Thwing's lips, multiplied its _rs_ as though they were reflected in an endless vista of mirrors. And it was not only the Mrs. Thwings who mourned. Had not the exquisite Hermia Croft, at the last Grafton Gallery show, stopped me before Gisburn's "Moon-dancers" to say, with tears in her eyes: "We shall not look upon its like again"?
#
# ...

# %%
tokens = re.findall(r"\w+|[^\w\s]", text, flags=re.UNICODE)

# %%
print(tokens)
# Out:
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '-', '-', 'though', 'a', 'good', 'fellow', 'enough', '-', '-', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his', 'glory', ',', 'he', 'had', 'dropped', 'his', 'painting', ',', 'married', 'a', 'rich', 'widow', ',', 'and', 'established', 'himself', 'in', 'a', 'villa', 'on', 'the', 'Riviera', '.', '(', 'Though', 'I', 'rather', 'thought', 'it', 'would', 'have', 'been', 'Rome', 'or', 'Florence', '.', ')', '"', 'The', 'height', 'of', 'his', 'glory', '"', '-', '-', 'that', 'was', 'what', 'the', 'women', 'called', 'it', '.', 'I', 'can', 'hear', 'Mrs', '.', 'Gideon', 'Thwing', '-', '-', 'his', 'last', 'Chicago', 'sitter', '-', '-', 'deploring', 'his', 'unaccountable', 'abdication', '.', '"', 'Of', 'course', 'it', "'", 's', 'going', 'to', 'send', 'the', 'value', 'of', 'my', 'picture', "'", 'way', 'up', ';', 'but', 'I', 'don', "'", 't', 'th
# ...

# %%
from collections import Counter
counts = Counter(tokens)
print(counts)
# Out:
# Counter({'-': 232, ',': 229, '.': 212, 'the': 167, '"': 137, 'I': 121, 'of': 98, 'to': 97, "'": 94, 'a': 82, 'and': 75, 'was': 69, 'it': 68, 'he': 64, 'his': 61, 'that': 55, 'had': 53, 'in': 40, 'my': 40, 's': 38, 'me': 37, 'him': 33, 'with': 32, 't': 31, 'on': 27, 'have': 25, 'you': 25, 'as': 24, '?': 24, '!': 24, 'one': 23, 'Mrs': 22, ';': 22, 'up': 21, 'at': 21, ':': 21, 'her': 20, 'she': 20, 'Gisburn': 19, 'been': 18, 'not': 17, 'Stroud': 17, 'so': 16, 'The': 16, 'Jack': 15, 'It': 15, 'for': 15, 'He': 15, 'by': 14, 'said': 14, 'but': 13, 'all': 13, 'an': 12, 'say': 12, 'out': 12, 'just': 12, 'see': 12, 'picture': 11, 'about': 11, 'only': 10, 'if': 10, 'But': 10, 'when': 10, 'painting': 9, 'himself': 9, 'would': 9, 'or': 9, 'what': 9, 'is': 9, 'they': 9, 'And': 9, 'through': 9, 'down': 9, 'be': 9, 'She': 9, 'know': 9, 'thought': 8, 'no': 8, 'were': 8, 'eyes': 8, 'like': 8, 'didn': 8, 'couldn': 8, 'Rickham': 7, 'who': 7, 'again': 7, 'own': 7, 'such': 7, 'because': 7, 'back': 7, 'pu
# ...

# %%
import torch
from torch import nn

class Embedder(nn.Module):
    def __init__(self,vocab):
        super().__init__()

        self.embedding = nn.Embedding()

    def foward(self,x):

        return self.embedding(x)

vocab = open("/Users/benjaminbrooke/PycharmProjects/Python_PyTroch/PyTorch Practice/0.Data/The Verdict.txt")

embedded_vocab = Embedder(vocab)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 16
#      12         return self.embedding(x)
#      14 vocab = open("/Users/benjaminbrooke/PycharmProjects/Python_PyTroch/PyTorch Practice/0.Data/The Verdict.txt")
# ---> 16 embedded_vocab = Embedder(vocab)
#
# Cell In[9], line 8, in Embedder.__init__(self, vocab)
#       5 def __init__(self,vocab):
#       6     super().__init__()
# ----> 8     self.embedding = nn.Embedding()
#
# TypeError: Embedding.__init__() missing 2 required positional arguments: 'num_embeddings' and 'embedding_dim'
